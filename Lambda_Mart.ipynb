# %% [markdown]
# # **Importing libraries**

# %%
import numpy as np
import pandas as pd
import random
import copy
from sklearn.tree import DecisionTreeRegressor
from multiprocessing import Pool
from datetime import datetime
import math

# NLTK Stopwords
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')

# Fasttext
# !pip install fasttext
import fasttext

# PyTorch
import torch
import torch.nn.functional as F

# To get vector embeddings
# !pip install sister
import sister

# Processing Parquets
# !pip install fastparquet
# !unzip Training_DSF.zip
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      |████████████████████████████████| 68 kB 7.1 MB/s
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.0-py3-none-any.whl (213 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext) (57.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fasttext) (1.21.6)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3161975 sha256=d2de98292ed4a81ac8cc54a91466ff17c9f3da1233def4a3d7367fc9565cef80
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.10.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sister
#   Downloading sister-0.1.10.tar.gz (24 kB)
# Requirement already satisfied: fasttext in /usr/local/lib/python3.7/dist-packages (from sister) (0.9.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sister) (1.21.6)
# Collecting Janome
#   Downloading Janome-0.4.2-py2.py3-none-any.whl (19.7 MB)
#      |████████████████████████████████| 19.7 MB 7.8 MB/s
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from sister) (3.6.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sister) (1.1.0)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext->sister) (57.4.0)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from fasttext->sister) (2.10.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim->sister) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim->sister) (1.7.3)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->sister) (5.2.1)
# Building wheels for collected packages: sister
#   Building wheel for sister (setup.py) ... done
#   Created wheel for sister: filename=sister-0.1.10-py3-none-any.whl size=5395 sha256=5b2da9a48157458fd4f741a63f47fe40fb3e424e3c5d30a6537d3b7bc8cfdfc8
#   Stored in directory: /root/.cache/pip/wheels/8f/2d/fe/f78c1b809e161ae840ebaf3f4a7b95350a300f89d439718042
# Successfully built sister
# Installing collected packages: Janome, sister
# Successfully installed Janome-0.4.2 sister-0.1.10
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fastparquet
#   Downloading fastparquet-0.8.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 27.7 MB/s
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (1.21.6)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (1.3.5)
# Collecting cramjam>=2.3.0
#   Downloading cramjam-2.5.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 52.2 MB/s
# Collecting fsspec
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 49.7 MB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->fastparquet) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->fastparquet) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.0->fastparquet) (1.15.0)
# Installing collected packages: fsspec, cramjam, fastparquet
# Successfully installed cramjam-2.5.0 fastparquet-0.8.1 fsspec-2022.7.1
# Archive:  Training_DSF.zip
#   inflating: Training_DSF/1636880019505.parquet
#   inflating: Training_DSF/1636880019628.parquet

# %% [markdown]
# # **Preparing the Dataset**

# %%
sentence_embedding = sister.MeanEmbedding(lang="en")
stop_words = set(stopwords.words('english'))

import os
directory = '/content/Training_DSF'
entries = os.listdir('/content/Training_DSF')
file_count = len([item for item in os.listdir(directory) if os.path.isfile(os.path.join(directory, item))])
article_prod = pd.DataFrame(columns = [])
 
# append datasets to the list
for i in range(file_count):
    temp_df = pd.read_parquet('/content/Training_DSF/'+entries[i])
    article_prod=article_prod.append(temp_df)
print(article_prod  ) 
#article_prod = pd.read_parquet('/content/Training_DS.zip', engine='fastparquet')
article_prod = article_prod.drop_duplicates(subset='id', keep="first")
article_prod = article_prod.drop('mid', axis=1)
article_prod = article_prod.drop('slug', axis=1)
article_prod = article_prod.drop('imageUrl', axis=1)
article_prod = article_prod.drop('metaDescription', axis=1)
article_prod = article_prod.drop('offset', axis=1)
article_prod = article_prod.drop('partition', axis=1)
article_prod = article_prod.drop('processTimestamp', axis=1)
article_prod = article_prod.drop('contentType', axis=1)
article_prod = article_prod.drop('updatedTimestamp', axis=1)
article_prod = article_prod.drop('hour', axis=1)

article_prod = article_prod.dropna()
article_prod['headline'] = article_prod['headline'].apply(lambda words: ' '.join(word.lower() for word in words.split() if word not in stop_words))
cleaned_text = article_prod['text'].apply(lambda words: ' '.join(word.lower() for word in words.split() if word not in stop_
# 160  Aditya Vikram Sengupta,Once Upon a Time in Cal...  2021-09-09
# 162  Indian hospitals,Dengue,Dengue Death,Dengue Fe...  2021-09-09
# 164   India vs England,India Tour of England,COVID-19,  2021-09-09

# %% [markdown]
# # Creating the Headline, Text, and Tag Similarity Matrices

# %%
def create_matrix(list):
    tensor_list = []
    for i in list:
        tensor_list.append(torch.tensor(sentence_embedding(i)))
    # Now we have the list of tensors.
    matrix = []
    for i in tensor_list:
        tmplist = []
        for j in tensor_list:
            tmplist.append(F.cosine_similarity(i, j, dim=0))
        matrix.append(tmplist)
    return matrix
    
headline_matrix = create_matrix(article_prod['headline'])
text_matrix = create_matrix(cleaned_text)
tag_matrix = create_matrix(cleaned_tags)

# %% [markdown]
# # Creating the Time Difference Matrix

# %%
n = article_prod.shape[0]
time_matrix = [[0 for x in range(n)] for y in range(n)] 
time_diff = []
for i in range(n):
    for j in range(n):
        time_matrix[i][j]= (datetime.strptime(article_prod['date'].values[i], "%Y-%m-%d")-datetime.strptime(article_prod['date'].values[j], "%Y-%m-%d")).days

# %% [markdown]
# # Combining Text/Headline similarity, and Time difference

# %%
final_dataframe = pd.DataFrame(columns = ['qid', 'id', 'grade' ,'features'])

# TODO: Figure out a proper value for the grades.
def findGrade(num):
  if(0.00 <= num and num < 0.1175 ):
     return 0
  elif (0.1175 < num and num < 0.2212):
     return 1
  elif(0.2212 < num and num < 0.393):
     return 2
  elif(0.393< num and num < 0.632  ):
      return 3
  elif(0.632 < num and num < 0.865):
      return 4
  else:
      return 5

for i in range(n):
    for j in range(n):
        if(i==j): continue;
        tmp = {'headline_qid':article_prod['headline'].values[i],'headline_id':article_prod['headline'].values[j],'qid': article_prod['id'].values[i], 'id': article_prod['id'].values[j], 'grade': findGrade(headline_matrix[i][j].item()),'features' : [text_matrix[i][j].item(),tag_matrix[i][j].item(),math.exp(-time_matrix[i][j])]}
        final_dataframe = final_dataframe.append(tmp,ignore_index=True)
        
final_dataframe['group_id']=final_dataframe.groupby(['qid'])['id'].ngroup()
final_dataframe['last_prediction'] = 0.0
final_dataframe = final_dataframe.sort_values(['group_id', 'last_prediction'], ascending=[True, False], kind='stable')
final_dataframe
# Out:
#                                        qid  \
# 1776  02547bd8-2264-4cd1-bd0c-a9941b8754b8
# 1777  02547bd8-2264-4cd1-bd0c-a9941b8754b8
# 1778  02547bd8-2264-4cd1-bd0c-a9941b8754b8
# 1779  02547bd8-2264-4cd1-bd0c-a9941b8754b8
# 1780  02547bd8-2264-4cd1-bd0c-a9941b8754b8
# ...                                    ...
# 2251  fe86068c-837e-4ccf-886a-9cc18b30e683
# 2252  fe86068c-837e-4ccf-886a-9cc18b30e683
# 2253  fe86068c-837e-4ccf-886a-9cc18b30e683
# 2254  fe86068c-837e-4ccf-886a-9cc18b30e683
# 2255  fe86068c-837e-4ccf-886a-9cc18b30e683
#
#                                         id grade  \
# 1776  d2db6348-a43d-44ab-8338-3dc83f7f7528     3
# 1777  a011dd67-2799-4f51-bf41-183b5e1ce181     3
# 1778  cbe5b8f3-f037-451e-ab22-208d9df333a4     3
# 1779  35c53239-7956-4fcf-aaaa-467dbcec7947     3
# 1780  969a0c45-30f0-4663-a3b8-b5860a518f2a     3
# ...                                    ...   ...
# 2251  c39b3862-8306-4f8d-8110-0d4457325ff4     4
# 2252  c0ee6c2a-06e0-49bd-9228-cc5a31d44439     4
# 2253  483a34df-bca9-4721-b5b8-64de331333ca     3
# 2254  164200d2-05dc-4508-9e53-b3ea23c0f873     4
# 2255  2f3a486f-a9ef-4dd4-9f32-4b12f0378507     3
#
#                                                features  \
# 1776  [0.9179891347885132, 0.8888632655143738, 7.389...
# 1777  [0.9084380269050598, 0.4314965307712555, 7.389...
# 1778  [0.848663330078125, 0.4284764528274536, 7.3890...
# 1779  [0.9111664295196533, 0.5041289925575256, 7.389...
# 1780  [0.818446695804596, 0.46078506112098694, 7.389...
# ...                                                 ...
# 2251         [0.92011559009552, 0.626268208026886, 1.0]
# 2252      [0.8891655206680298, 0.5255205035209656, 1.0]
# 2253      [0.8963913321495056, 0.7311475872993469, 1.0]
# 2254      [0.9430419206619263, 0.6924434900283813, 1.0]
# 2255      [0.8790006041526794, 0.5524431467056274, 1.0]
#
#                                             headline_id  \
# 1776  taliban executes brother former afghan vice-pr...
# 1777  indian men’s cricket team’s tryst with covid-1...
# 1778               10 haunting photographs 9/11 attacks
# 1779  mumbai: 30-yr-old woman raped, brutalised; acc...
# 1780  beyond fruity smell: ingredients floor cleaner...
# ...                                                 ...
# 2251  'we are still amid second covid wave': health ...
# 2252  jee main 2021 session 4 result to be declared ...
# 2253  gyanvapi mosque: allahabad hc stays varanasi c...
# 2254  'save us': scary scenes mystery fever grips ut...
# 2255  fifth test match vs england to go ahead schedu...
#
#                                            headline_qid  group_id  \
# 1776  no phd master's degree valuable today: taliban...         0
# 1777  no phd master's degree valuable today: taliban...         0
# 1778  no phd master's degree valuable today: taliban...         0
# 1779  no phd master's degree valuable today: taliban...         0
# 1780  no phd master's degree valuable today: taliban...         0
# ...                                                 ...       ...
# 2251  review: 'once upon time calcutta' tenderly cap...        48
# 2252  review: 'once upon time calcutta' tenderly cap...        48
# 2253  review: 'once upon time calcutta' tenderly cap...        48
# 2254  review: 'once upon time calcutta' tenderly cap...        48
# 2255  review: 'once upon time calcutta' tenderly cap...        48
#
#       last_prediction
# 1776              0.0
# 1777              0.0
# 1778              0.0
# 1779              0.0
# 1780              0.0
# ...               ...
# 2251              0.0
# 2252              0.0
# 2253              0.0
# 2254              0.0
# 2255              0.0
#
# [2352 rows x 8 columns]

# %%
def compute_lambdas(lambdas_per_query):
    lambdas_per_query = lambdas_per_query.sort_values(['group_id', 'last_prediction'], ascending=[True, False], kind='stable')
    lambdas_per_query['display_rank'] = lambdas_per_query.groupby('group_id').cumcount()

    #TBD - How do generalize this to any metric?
    lambdas_per_query['discount'] = 1 / np.log2(2 + lambdas_per_query['display_rank'])
    lambdas_per_query['gain'] = (2**lambdas_per_query['grade'] - 1)

    # swaps dataframe holds each pair-wise swap computed (shrink columns for memory?)   
    # Optimization of swaps = lambdas_per_query.merge(lambdas_per_query, on='qid', how='outer')
    # to limit to just needed columns
    to_swap = lambdas_per_query[['group_id', 'display_rank', 'grade', 'last_prediction', 'discount', 'gain']]
    #to_swap = lambdas_per_query
    swaps = to_swap.merge(to_swap, on='group_id', how='outer')

    # delta - delta in DCG due to swap
    swaps['delta'] = np.abs((swaps['discount_x'] - swaps['discount_y']) * (swaps['gain_x'] - swaps['gain_y']))
    
    # rho - based on current model prediction delta
    swaps['rho'] = 1 / (1 + np.exp(swaps['last_prediction_x'] - swaps['last_prediction_y']))
    
    # If you want to be pure gradient boosting, weight reweights each models prediction
    # I haven't found this to matter in practice
    swaps['weight'] = swaps['rho'] * (1.0 - swaps['rho']) * swaps['delta']

    # Compute lambdas (the next model in ensemble's predictors) when grade_x > grade_y
    swaps['lambda'] = 0
    slice_x_better =swaps[swaps['grade_x'] > swaps['grade_y']]
    swaps.loc[swaps['grade_x'] > swaps['grade_y'], 'lambda'] = slice_x_better['delta'] * slice_x_better['rho']
    
    # accumulate lambdas and add back to model
    lambdas_x = swaps.groupby(['group_id', 'display_rank_x'])['lambda'].sum().rename('lambda')
    lambdas_y = swaps.groupby(['group_id', 'display_rank_y'])['lambda'].sum().rename('lambda')

    weights_x = swaps.groupby(['group_id', 'display_rank_x'])['weight'].sum().rename('weight')
    weights_y = swaps.groupby(['group_id', 'display_rank_y'])['weight'].sum().rename('weight')
    
    weights = weights_x + weights_y
    lambdas = lambdas_x - lambdas_y

    lambdas_per_query = lambdas_per_query.merge(lambdas, 
                                                left_on=['group_id', 'display_rank'], 
                                                right_on=['group_id', 'display_rank_x'], 
                                                how='left')
    lambdas_per_query = lambdas_per_query.merge(weights, 
                                                left_on=['group_id', 'display_rank'], 
                                                right_on=['group_id', 'display_rank_x'], 
                                                how='left')

    return lambdas_per_query

# %%
ensemble=[]
def lambda_mart_pure(final_dataframe, rounds=20,
                     learning_rate=0.1, max_leaf_nodes=8):

    lambdas_per_query = final_dataframe.copy()
    lambdas_per_query['last_prediction'] = 0.0

    for i in range(0, rounds):
        print(f"round {i}")

        # ------------------
        #1. Build pair-wise predictors for this round
        lambdas_per_query = compute_lambdas(lambdas_per_query)


        # ------------------
        #2. Train a regression tree on this round's lambdas
        features = lambdas_per_query['features'].tolist()
        new_tree = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes)
        new_tree.fit(features, lambdas_per_query['lambda'])    

        # -------------------
        #4. Add to ensemble, recreate last prediction
        ensemble.append(new_tree)
        next_predictions = new_tree.predict(features)
        lambdas_per_query['last_prediction'] += (next_predictions * learning_rate) 
        
        print(lambdas_per_query.loc[0, ['grade', 'last_prediction']])
        
        print("Train DCGs")
        lambdas_per_query['discounted_gain'] = lambdas_per_query['gain'] * lambdas_per_query['discount'] 
        dcg = lambdas_per_query[lambdas_per_query['display_rank'] < 10].groupby('qid')['discounted_gain'].sum().mean()
        print("mean   ", dcg)
        print("----------")
        
        lambdas_per_query = lambdas_per_query.drop(['lambda', 'weight'], axis=1)
    return lambdas_per_query


lambdas_per_query = lambda_mart_pure(final_dataframe=final_dataframe, rounds=50, max_leaf_nodes=10, learning_rate=0.01)
model = ensemble[len(ensemble) -1]
# Out:
# round 0
# grade                     3
# last_prediction    0.166165
# Name: 0, dtype: object
# Train DCGs
# mean    40.75633230942108
# ----------
# round 1
# grade                     3
# last_prediction    0.204197
# Name: 0, dtype: object
# Train DCGs
# mean    49.4376976504061
# ----------
# round 2
# grade                     3
# last_prediction   -0.049018
# Name: 0, dtype: object
# Train DCGs
# mean    53.795958230677456
# ----------
# round 3
# grade                     3
# last_prediction    0.120857
# Name: 0, dtype: object
# Train DCGs
# mean    54.10998868503444
# ----------
# round 4
# grade                     3
# last_prediction   -0.035595
# Name: 0, dtype: object
# Train DCGs
# mean    53.94067791248284
# ----------
# round 5
# grade                     3
# last_prediction    0.238209
# Name: 0, dtype: object
# Train DCGs
# mean    54.460077030478026
# ----------
# round 6
# grade                     3
# last_prediction    0.293041
# Name: 0, dtype: object
# Train DCGs
# mean    54.34739951541245
# ----------
# round 7
# grade                     3
# last_prediction    0.496107
# Name: 0, dtype: object
# Train DCGs
# mean    54.28992356033222
# ----------
# round 8
# grade                     3
# last_prediction    0.637021
# Name: 0, dtype: object
# Train DCGs
# mean    55.97646837191291
# ----------
# round 9
# grade                     3
# last_prediction    0.667473
# Name: 0, dtype: object
# Train DCGs
# mean    56.29808647832531
# ----------
# round 10
# grade                    4
# last_prediction    0.81077
# Name: 0, dtype: object
# Train DCGs
# mean    56.588364222672716
# ----------
# round 11
# grade                     4
# last_prediction    1.197071
# Name: 0, dtype: object
# Train DCGs
# mean    56.55890879021702
# ----------
# round 12
# grade                     4
# last_prediction    1.345841
# Name: 0, dtype: object
# Train DCGs
# mean    56.691642694708456
# ----------
# round 13
# grade                     4
# last_prediction    1.397466
# Name: 0, dtype: object
# Train DCGs
# mean    57.4370992285222
# ----------
# round 14
# grade                     4
# last_prediction    1.471301
# Name: 0, dtype: object
# Train DCGs
# mean    57.469279069368845
# ----------
# round 15
# grade                     4
# last_prediction    1.523406
# Name: 0, dtype: object
# Train DCGs
# mean    57.59191853943448
# ----------
# round 16
# grade                     4
# last_prediction    1.557004
# Name: 0, dtype: object
# Train DCGs
# mean    57.71516382001447
# ----------
# round 17
# grade                     4
# last_prediction    1.589338
# Name: 0, dtype: object
# Train DCGs
# mean    57.97881461613755
# ----------
# round 18
# grade                     4
# last_prediction    1.619925
# Name: 0, dtype: object
# Train DCGs
# mean    58.066223680964626
# ----------
# round 19
# grade                     4
# last_prediction    1.649514
# Name: 0, dtype: object
# Train DCGs
# mean    58.027933329875275
# ----------
# round 20
# grade                    4
# last_prediction    1.67722
# Name: 0, dtype: object
# Train DCGs
# mean    58.22193589426721
# ----------
# round 21
# grade                     4
# last_prediction    1.719088
# Name: 0, dtype: object
# Train DCGs
# mean    58.25293987481844
# ----------
# round 22
# grade                    4
# last_prediction    1.75835
# Name: 0, dtype: object
# Train DCGs
# mean    58.26919885118924
# ----------
# round 23
# grade                     4
# last_prediction    1.782282
# Name: 0, dtype: object
# Train DCGs
# mean    58.27126563049352
# ----------
# round 24
# grade                     4
# last_prediction    1.805088
# Name: 0, dtype: object
# Train DCGs
# mean    58.26030361240534
# ----------
# round 25
# grade                     4
# last_prediction    1.826824
# Name: 0, dtype: object
# Train DCGs
# mean    58.346529959413935
# ----------
# round 26
# grade                     4
# last_prediction    1.915567
# Name: 0, dtype: object
# Train DCGs
# mean    58.365703424417546
# ----------
# round 27
# grade                     4
# last_prediction    2.040375
# Name: 0, dtype: object
# Train DCGs
# mean    58.36521545392786
# ----------
# round 28
# grade                     4
# last_prediction    2.058654
# Name: 0, dtype: object
# Train DCGs
# mean    58.3486959399002
# ----------
# round 29
# grade                    4
# last_prediction    2.16065
# Name: 0, dtype: object
# Train DCGs
# mean    58.36800910264375
# ----------
# round 30
# grade                     4
# last_prediction    2.173003
# Name: 0, dtype: object
# Train DCGs
# mean    58.385513994857845
# ----------
# round 31
# grade                     4
# last_prediction    2.265484
# Name: 0, dtype: object
# Train DCGs
# mean    58.338319737499816
# ----------
# round 32
# grade                     4
# last_prediction    2.366328
# Name: 0, dtype: object
# Train DCGs
# mean    58.36361704166395
# ----------
# round 33
# grade                    4
# last_prediction    2.39242
# Name: 0, dtype: object
# Train DCGs
# mean    58.44060242305332
# ----------
# round 34
# grade                     4
# last_prediction    2.484747
# Name: 0, dtype: object
# Train DCGs
# mean    58.52714328861152
# ----------
# round 35
# grade                     4
# last_prediction    2.580499
# Name: 0, dtype: object
# Train DCGs
# mean    58.54472511093651
# ----------
# round 36
# grade                     4
# last_prediction    2.655675
# Name: 0, dtype: object
# Train DCGs
# mean    58.56515161903636
# ----------
# round 37
# grade                    4
# last_prediction    2.75135
# Name: 0, dtype: object
# Train DCGs
# mean    58.62628515074442
# ----------
# round 38
# grade                     4
# last_prediction    2.820836
# Name: 0, dtype: object
# Train DCGs
# mean    58.6595401337524
# ----------
# round 39
# grade                     4
# last_prediction    2.905403
# Name: 0, dtype: object
# Train DCGs
# mean    58.663677858740215
# ----------
# round 40
# grade                     4
# last_prediction    2.970382
# Name: 0, dtype: object
# Train DCGs
# mean    58.66563135577631
# ----------
# round 41
# grade                     4
# last_prediction    2.973231
# Name: 0, dtype: object
# Train DCGs
# mean    58.66263712663723
# ----------
# round 42
# grade                     4
# last_prediction    3.032153
# Name: 0, dtype: object
# Train DCGs
# mean    58.67946169848535
# ----------
# round 43
# grade                     4
# last_prediction    3.035326
# Name: 0, dtype: object
# Train DCGs
# mean    58.74493093239835
# ----------
# round 44
# grade                     4
# last_prediction    3.038156
# Name: 0, dtype: object
# Train DCGs
# mean    58.8145519150937
# ----------
# round 45
# grade                     4
# last_prediction    3.108036
# Name: 0, dtype: object
# Train DCGs
# mean    58.807264446510565
# ----------
# round 46
# grade                    4
# last_prediction    3.11683
# Name: 0, dtype: object
# Train DCGs
# mean    58.8231572178967
# ----------
# round 47
# grade                    4
# last_prediction    3.12399
# Name: 0, dtype: object
# Train DCGs
# mean    58.86498972584849
# ----------
# round 48
# grade                     4
# last_prediction    3.189014
# Name: 0, dtype: object
# Train DCGs
# mean    58.86498972584849
# ----------
# round 49
# grade                     4
# last_prediction    3.192744
# Name: 0, dtype: object
# Train DCGs
# mean    58.90999975525478
# ----------

# %%
import heapq
r = final_dataframe.shape[0]
# Given an article id
def rank(article_h,m):
 H = []
 
 for i in range(r):
     if(article_h == final_dataframe.iloc[i]['headline_qid']):
         heapq.heappush(H,[-model.predict(np.array(final_dataframe.iloc[i]['features']).reshape(1, -1)),final_dataframe.iloc[i]['headline_id']])
 k_elems = []
 for i in range(m):
     k_elems.append(heapq.heappop(H))
 return k_elems

# %%
z=np.array_split(rank('kbc 13: amitabh bachchan recalls when farah khan scolded him set',10),10)
print("the ranked list of articles is :")
print (z)
# Out:
# the ranked list of articles is :
# [array([[array([-3.2276144]),
#         'captain vikram batra, the ‘shershaah’ pakistan army feared during kargil war']],
#       dtype=object), array([[array([-3.2276144]),
#         'only parents have right: saba ali khan kareena-saif naming their son jeh']],
#       dtype=object), array([[array([-3.2276144]),
#         "review: 'laabam' serves communism on a fast-food platter"]],
#       dtype=object), array([[array([-3.2276144]),
#         "review: 'once upon time calcutta' tenderly captures city flux"]],
#       dtype=object), array([[array([-3.2276144]),
#         "watch trailer priyanka, keanu reeves' 'the matrix resurrections'"]],
#       dtype=object), array([[array([-0.37307623]),
#         "'no room for sexual harassers': journos ask wion end mj akbar's employment"]],
#       dtype=object), array([[array([-0.37307623]),
#         "indian squad for 2021 men's t20 wc: dhawan out, ashwin in & dhoni mentor team"]],
#       dtype=object), array([[array([-0.09725957]),
#         "'save us': scary scenes mystery fever grips uttar pradesh"]],
#       dtype=object), array([[array([-0.09725957]),
#         "'we are still amid second covid wave': health secretary"]],
#       dtype=object), array([[array([-0.09725957]),
#         'carbon dating reveals 3,200-year-old civilisation tamil nadu: mk stalin']],
#       dtype=object)]
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = getattr(asarray(obj), method)(*args, **kwds)

# %%
print("The ranked list of articles is :")
for i in range(10):
  print(i+1,". ",end="")
  print(z[i][0][1])
# Out:
# The ranked list of articles is :
# 1 . captain vikram batra, the ‘shershaah’ pakistan army feared during kargil war
# 2 . only parents have right: saba ali khan kareena-saif naming their son jeh
# 3 . review: 'laabam' serves communism on a fast-food platter
# 4 . review: 'once upon time calcutta' tenderly captures city flux
# 5 . watch trailer priyanka, keanu reeves' 'the matrix resurrections'
# 6 . 'no room for sexual harassers': journos ask wion end mj akbar's employment
# 7 . indian squad for 2021 men's t20 wc: dhawan out, ashwin in & dhoni mentor team
# 8 . 'save us': scary scenes mystery fever grips uttar pradesh
# 9 . 'we are still amid second covid wave': health secretary
# 10 . carbon dating reveals 3,200-year-old civilisation tamil nadu: mk stalin
